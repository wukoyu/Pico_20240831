# %%
import random #匯入內建random Module
import time #匯入內建time Module

for i in range(100):
    print(random.randint(1,10))
    time.sleep(1)

# %%
import requests #使用pip install requests指令在虛擬環境安裝外部module 「requests」後用import匯入
# 匯入後要找到Module說明書以及知道如何使用
#pip是套件管理工具
# Module裡面有function、class、常數
r = requests.get(url='https://api.github.com/events')
type(r)
# Out:
# requests.models.Response

# %%
#Response object包含三要素；Attribute、Property、Method()方法
r.text
# Out:
# '[{"id":"41926729257","type":"IssuesEvent","actor":{"id":3270528,"login":"normen","display_login":"normen","gravatar_id":"","url":"https://api.github.com/users/normen","avatar_url":"https://avatars.githubusercontent.com/u/3270528?"},"repo":{"id":721155292,"name":"normen/obs-mcu","url":"https://api.github.com/repos/normen/obs-mcu"},"payload":{"action":"closed","issue":{"url":"https://api.github.com/repos/normen/obs-mcu/issues/5","repository_url":"https://api.github.com/repos/normen/obs-mcu","labels_url":"https://api.github.com/repos/normen/obs-mcu/issues/5/labels{/name}","comments_url":"https://api.github.com/repos/normen/obs-mcu/issues/5/comments","events_url":"https://api.github.com/repos/normen/obs-mcu/issues/5/events","html_url":"https://github.com/normen/obs-mcu/issues/5","id":2508343812,"node_id":"I_kwDOKvv03M6VgkoE","number":5,"title":"Questions and official docker image","user":{"login":"gravelfreeman","id":44218371,"node_id":"MDQ6VXNlcjQ0MjE4Mzcx","avatar_url":"https://avatar
# ...
